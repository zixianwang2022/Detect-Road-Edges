# %% [markdown]
# # Self Study Project: #
# ## Road Edge Detecting ##
#
# #### Author: Zixan Wang ###
# #### Email: ziw081@ucsd.edu ###
# #### Class: CSE 152A ###
#
# ### Goal: Be able to simultaneously detect road edges while driving/walking ###
#
# ### The entire project will be divided into 3 sections. ###
#
#  1. Be able to detect edges of a single image
#  2. Be able to detect edges of a video
#  3. Use GPU to accelerate the running time.
#
# ## Please send any opinions and/or feedback to Zixian at ziw081@ucsd.edu. Any comments are appreciated!

# %%
# Setup
import numpy as np
from time import time
from skimage import io
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.signal import convolve
from collections import defaultdict
from PIL import Image
import cv2

# %% [markdown]
# # Section 1: #
# ### Descriptions: ###
# Detect road edges through finding derivatives of the values in a grayed version of the input image.
#
# ### Steps: ###
# 1. Convert an input image into a gray color image.
# 2. Smoothe the gray image using convolution.
# 3. Find the gradient of the image.
# 4. Set threshold to ensure image correctly outputed an image with edges.

# %%
def gaussian2d(filter_size, sig):
    """
    Creates 2D Gaussian kernel with side length `filter_size` and a sigma of `sig`.
    Source: https://stackoverflow.com/a/43346070
    """
    ax = np.arange(-filter_size // 2 + 1., filter_size // 2 + 1.)
    xx, yy = np.meshgrid(ax, ax)
    kernel = np.exp(-0.5 * (np.square(xx) + np.square(yy)) / np.square(sig))
    return kernel / np.sum(kernel)

# %%
def smooth(image, sig):
    """ 
    Args:
        image: input image (h, w)
        
    Returns:
        smooth_image: smoothened version of the input image (h, w) 
    """
    
    smooth_image = np.zeros_like(image)
    
    smooth_image = convolve (image, gaussian2d(9, sig), mode='same')

#     smooth_kernal = np.array ([ [1,4,7,4,1], [4,16,26,16,4], [7,26,41,26,7], [1,4,7,4,1], [4,16,26,16,4]])
    
#     smooth_image = convolve (image, smooth_kernal, mode='same')
    
    return smooth_image

# %%
def gradient(image):
    """ 
    Args:
        image: input image (h, w)

    Returns:
        g_mag: gradient magnitude (h, w)
        g_theta: gradient direction (h, w)
    """
        
    g_mag = np.zeros_like(image)
    g_theta = np.zeros_like(image)
    

    part_x_kernal = np.array ([ [1,0,-1], [2,0,-2], [1,0,-1]])
    part_y_kernal = part_x_kernal.T
    
    g_x = convolve (image, part_x_kernal, mode='same')
    g_y = convolve (image, part_y_kernal, mode='same')
    
    g_mag = np.sqrt (g_x**2 + g_y**2)
    g_theta = np.arctan2 (g_y, g_x)

     
    
    return g_mag, g_theta

# %%
def edge_detect(image, sig):
    """Perform edge detection on the image."""
    smoothed = smooth(image, sig)
    g_mag, g_theta = gradient(smoothed)
    return smoothed, g_mag, g_theta

# %%
# %%time

# Load image in grayscale
# image = io.imread('road_set1_1.jpg', as_gray=True)
image = io.imread('road_set1_2.png', as_gray=True)
print (image.shape)
smoothed, g_mag1, g_theta = edge_detect(image, 5)
# Out:
# (484, 644)
# CPU times: user 70.6 ms, sys: 19.6 ms, total: 90.3 ms
# Wall time: 97.5 ms

# %%
print('Original:')
plt.imshow(image, cmap='gray')
# plt.imshow(image)
plt.show()

print('Smoothed:')
plt.imshow(smoothed, cmap='gray')
plt.show()

print('Gradient magnitude:')
plt.imshow(g_mag1, cmap='gray')
plt.show()

print('Gradient direction:')
plt.imshow(g_theta, cmap='gray')
plt.show()
# Out:
# Original:
# Smoothed:
# Gradient magnitude:
# Gradient direction:

# %%
def add_red_line (image_rgb, sig, threshold):
    """
    Given a 3 dimensional array, find its edges in gray color, then plot the edges
    in red to the given image
    
    Input: 3d image array
    
    output: 3d image array
    """
    
    rgb_to_gray = 246
    
    size = image_rgb.shape
    
    
    # Create a gray scale image from input rgb image
    image_gray = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2GRAY)/rgb_to_gray
#     image_gray2 = io.imread('road_set1_2.png', as_gray=True)


    
    smoothed, img_mag, img_theta = edge_detect(image_gray, sig)
    
    # add edges in red to the given image
    red_img = np.zeros_like (image_rgb)
    
    # Array copy
    for i in range (size[0]):
        for j in range (size[1]):
            for k in range (size[2]):
                red_img [i,j,k] = image_rgb [i,j,k]
    
    
    start0 = size[0]//100
    end0 = size[0] - size[0]//100
    
    start1 = size[1]//100
    end1 = size[1] - size[1]//100
    
    red_lines_loc = (img_mag[start0:end0,start1:end1] < (1-threshold))
    
    red_img[start0:end0,start1:end1,1] = red_img[start0:end0,start1:end1,1] * red_lines_loc
    red_img[start0:end0,start1:end1,2] = red_img[start0:end0,start1:end1,2] * red_lines_loc

    
    
    return red_img, smoothed, img_mag, img_theta

# %%
# %%time

image_no_gray = io.imread('road_set1_2.png')

red_img, image_no_gray_smoothed, img_mag, img_theta = add_red_line (image_no_gray, 5, 0.77)

# print (sum(sum((image_no_gray == image_no_gray_smoothed) == 0)))
# Out:
# CPU times: user 267 ms, sys: 18.9 ms, total: 286 ms
# Wall time: 295 ms

# %%
# image_no_gray = io.imread('road_set1_1.jpg', as_gray=False)
# image_no_gray = io.imread('road_set1_2.png', as_gray=False)
# image_no_gray_dup = io.imread('road_set1_2.png', as_gray=False)
# print (type (image_no_gray))

print (image_no_gray.shape)
plt.imshow (image_no_gray)
plt.show()

plt.imshow (image_no_gray_smoothed)
plt.show()

# plt.imshow (img_mag)
# plt.show()

# plt.imshow (img_theta)
# plt.show()

plt.imshow (red_img)
plt.show()
# Out:
# (484, 644, 4)

# %%
plt.imshow (img_mag)
plt.show()

plt.imshow (img_theta)
plt.show()

# %%
# img_theta[320:325,480:485]=100
# img_theta[320:325,520:525]=100
# img_theta[350:355,480:485]=100
# img_theta[350:355,520:525]=100

# plt.imshow (img_theta)
# plt.show()

# print (img_theta[320:350, 480:520])
print (image.shape)
# Out:
# (484, 644)

# %%
def point_direction (image, mag, threshold):
    
    # --------------------------------
    # ---- Initialization ----
    # --------------------------------
    
    width  = mag.shape[1]
    height = mag.shape[0]
    
    size = 100
    
    width_ex = int (width - (width // size)*size)
    y_start = int (width_ex//2)
    
    height_ex = int (height - (height // size)*size)
    x_start = int (height_ex//2)
    
    gridy = int ((height - y_start)//size)
    gridx = int ((width  - x_start)//size)
    
#     print (y_start,x_start)
#     print (gridy, gridx)
    
    gridy_reduced = gridy-2
    gridx_reduced = gridx-2
    
    grid = np.zeros ([gridy,gridx])
    reduced = np.zeros ([gridy_reduced,gridx_reduced])
    
    
    # --------------------------------
    # --Divide input image into grids-
    # --------------------------------
    for y in range (y_start, height-size, size):
        for x in range (x_start, width-size, size):
            if (np.sum (mag [y:y+size,x:x+size]) > threshold):
                grid [int(y//size),int(x//size)] = 1
            
    # --------------------------------
    # Get ride of the outer edge, assign to grid reduce
    # --------------------------------
    for y in range (1,gridy-1,1):
        for x in range (1,gridx-1,1):
            reduced[y-1,x-1] = grid[y,x]
     
    
    # --------------------------------------
    # ---- Finding road center position ----
    # --------------------------------------
    listy = []
    listx = []
    
    for y in range (gridy_reduced):
        for x in range (gridx_reduced):
            if (reduced[y,x] == 0):
                listy.append (y)
                listx.append (x)
                
    medy = int (np.median (listy))
    medx = int (np.median (listx))
    
#     print (medy,medx)
    
    
    # ----------------------------------
    # ---- setting arrow parameters ----
    # ----------------------------------
    arrowY = y_start + size*(1+medx)
    arrowX = x_start + size*(1+medx)
    
    arrBodyWid = 20
    arrBodyHei = 100
    
    arrHeadWid = 40
    arrHeadHei = 40
    
    arrWid = 40
    arrHei = 140
    
    arr = np.ones ([arrBodyHei+arrHeadHei,arrHeadWid])
    
    # Draw arrow body
    for y in range (40,arr.shape[0],1):
        for x in range (int (arrBodyWid/2),int(arr.shape[1]-arrBodyWid/2),1):
            arr [y,x] = 0
            
#     # Draw arrow head-left
    for x in range (0,int (arr.shape[1]/2),1):
        for y in range (arrHeadHei,arrHeadHei-x,-1):
            arr [y,x] = 0
            
    # Draw arrow head-right
    for x in range (20,40,1):
        for y in range (x,arrHeadHei,1):
#             print (y,x)
            arr [y,x] = 0
            
    
    # ----------------------------------
    # ---- draw arrow on the image  ----
    # ----------------------------------
    
    arr_img = np.zeros_like (image)
    
    imgShape = image.shape
    
    # Array copy
    for i in range (imgShape[0]):
        for j in range (imgShape[1]):
            for k in range (imgShape[2]):
                arr_img [i,j,k] = image [i,j,k]
                
    arr_img [arrowY:arrowY+arrHei, arrowX:arrowX+arrWid,1] = \
                            arr_img [arrowY:arrowY+arrHei, arrowX:arrowX+arrWid,1] * arr
    arr_img [arrowY:arrowY+arrHei, arrowX:arrowX+arrWid,2] = \
                            arr_img [arrowY:arrowY+arrHei, arrowX:arrowX+arrWid,2] * arr
            
    return grid, reduced, arr_img

# %%
# %%time

grid,gridR,arrImage = point_direction (red_img, img_mag, 100000)
# Out:
# CPU times: user 255 ms, sys: 4 ms, total: 259 ms
# Wall time: 257 ms

# %%
plt.imshow (arrImage)
plt.show()

# %% [markdown]
# # Section 2: #
# ### Descriptions: ###
# Use cv2 library to load a video. Then for each frame of the video, it does an image processing that detect the edges.
#
# ### Steps: ###
# 1. Read a video using cv2.VideoCapture
# 2. Open up the video by individual frames.
# 3. Call add_red_line method to add the edges of the road to this image.
# 4. Wait and see it runs
#
# ### Disadvantage: ###
# Each frame is converted into a 2D array, and it is processed through a series of oeprations. The runtime for 1 frame is $O(n^2)$. The video I loaded has 30 frames per seconds and is 22 seconds long. So this will run for 660 times of the entire edge detecting process.
#
# ### Comments: ###
# To be able to see that the video is actually been processed, I loaded a random number generator, and give it $4/5$ chance to continue to next frame. I also commented out the adding arrow operations to facilitate the runtime for each frame.
#
# Because I am using cv2.imshow, this will load a new window to demonstrate the resulting image. I noticed that for Mac, the window does not have a close button. So to close the window I have to restart the Kernal. If to run it again, restart the Kernal and runAll.

# %%
# Load video 
vid1 = cv2.VideoCapture ('road_set1_video.mp4')

# Check if camera open
if not vid1.isOpened():
    print ('Video not opened')
else:
    print ('Video dimensions: ', vid1.get(cv2.CAP_PROP_FRAME_WIDTH), vid1.get(cv2.CAP_PROP_FRAME_HEIGHT))
    print ('Video FPS: ', vid1.get(cv2.CAP_PROP_FPS))
    


# vid1.release ()
# Out:
# Video dimensions:  1280.0 720.0
# Video FPS:  30.0

# %%
import time 
import random

while (vid1.isOpened()):
    
    if (np.random.rand() > 0.2):
        continue
    
    
    success, vid1Frame = vid1.read()
    if success:
        corrected_rgb = vid1Frame [:,:,(0,1,2)]
        vid1_i1, vid1_i2, vid1_i3, vid1_i4 = add_red_line (corrected_rgb, 5, 0.77)
#         vid1_i5,vid1_i6,vid1_i7 = point_direction (vid1_i1, vid1_i3, 100000)
    
    print ('Another Round')
    
    cv2.imshow('camOut', vid1_i1)
    cv2.waitKey (1)

#     plt.imshow (vid1_i1)
#     plt.show
    
    
vid1.release ()
# Out:
# Another Round
# Another Round
# Another Round
# Another Round
# Another Round
# Another Round
# Another Round
# Another Round
# Another Round

# %% [markdown]
# # Section 3 #
# ## Compile using GPU
# ### Description: ###
# Rewrite some of the functions above to run in GPU.
#
# ### Steps ###
# 1. From numba import cuda
# 2. Rewrite Gradient function to run in GPU.
# 3. Rewrite add_red_line function to run in GPU.
# 4. Rewrite point_direction to run in GPU.
#
# ### Challenges currently facing ###
# 1. I tried writing cuda code on remote server Expanse provided by SDSC. However, I could not find a way to import cv2 package, although I tried a lot of ways such as pip install cv2. I think the problem is with how Expanse created a secure server to the jupyter notebook, and modules/packages could not go through the notebook
# 2. I tried implementing cuda code on my local PC. However, I was stuck at importing numba. I pip install numba, but it outputed me that internal error occurs when importing numba at the first cell. I looked online, but could not find a solution.
#
#
# ### Possible alternatives ###
# 1. Contact user service at SDSC to see how to include cv2 package on the remote server.

# %% [markdown]
# ## Please send your opinions and/or feedback to Zixian at ziw081@ucsd.edu.
# ## Any comments are appreciated!
